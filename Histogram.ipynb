# %% [markdown]
# # Ex. No: 03
# ## Histogram Equalization Using OpenCV (Grayscale & Color Images)
#
# ## Name : THARUN V    Reg. No : 212224230290

# %% [markdown]
# ### Write a Python program using OpenCV to perform histogram equalization on the given grayscale image **"parrot.jpg"**.
#
# The program should:
#
# - Import the required libraries (**OpenCV, NumPy, Matplotlib**).
# - Read the image **"parrot.jpg"** in **grayscale** format.
# - Display the grayscale image and plot its histogram.
# - Perform **histogram equalization** on the grayscale image using `cv2.equalizeHist()` to enhance its contrast.
# - Using Matplotlib, display the following in a **2 × 2 grid layout**:
#   - Original Grayscale Image
#   - Histogram of Original Image
#   - Enhanced (Equalized) Image
#   - Histogram of Enhanced Image

# %%
# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image in grayscale format
img = cv2.imread("tha.jpg", 0)

# Display the image
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 img = cv2.imread("tha.jpg", 0)
#       4 # Display the image
# ----> 5 plt.imshow(img, cmap="gray")
#       6 plt.axis("off")
#       7 plt.show()
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\axes\_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:648, in _ImageBase._normalize_image_array(A)
#     646 A = cbook.safe_masked_invalid(A, copy=True)
#     647 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 648     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                     f"converted to float")
#     650 if A.ndim == 3 and A.shape[-1] == 1:
#     651     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Display the grayscale image.
plt.imshow(img, cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Display the grayscale image.
# ----> 2 plt.imshow(img, cmap='gray')
#       3 plt.title('Original Grayscale Image')
#       4 plt.axis('off')
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\axes\_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:648, in _ImageBase._normalize_image_array(A)
#     646 A = cbook.safe_masked_invalid(A, copy=True)
#     647 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 648     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                     f"converted to float")
#     650 if A.ndim == 3 and A.shape[-1] == 1:
#     651     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Plot the histogram of the grayscale image
plt.hist(img.ravel(),256,range = [0, 256]);
plt.title('Original Image')
plt.show()

# %%
# Perform histogram equalization
img_eq = cv2.equalizeHist(img)

# %%
# Display [1] the Original Image (Gray Image) and its Histogram, and [2] the Enhanced Image and its Histogram using a 2×2 layout in Matplotlib.
plt.hist(img_eq.ravel(), 256, range = [0, 256]); 
plt.title('Equalized Histogram')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Display [1] the Original Image (Gray Image) and its Histogram, and [2] the Enhanced Image and its Histogram using a 2×2 layout in Matplotlib.
# ----> 2 plt.hist(img_eq.ravel(), 256, range = [0, 256]);
#       3 plt.title('Equalized Histogram')
#
# AttributeError: 'NoneType' object has no attribute 'ravel'

# %% [markdown]
# ### Write a Python program using OpenCV to perform color image enhancement through histogram equalization in the HSV color space on the given image **"parrot.jpg"**.
#
# The program should:
#
# - Import the required libraries (**OpenCV, NumPy, Matplotlib**).
# - Read the color image **"parrot.jpg"**.
# - Plot the **histogram of the original color image** (use the **B, G, and R** channels).
# - Convert the image from **BGR to HSV** color space.
# - Apply **histogram equalization** to one specific channel to improve brightness and contrast using `cv2.equalizeHist()`.
# - Convert the enhanced HSV image back to **BGR** format.
# - Using Matplotlib, display the following in a **2 × 2 grid layout**:
#   - Original Color Image
#   - Histogram of Original Image (BGR channels)
#   - Enhanced Color Image
#   - Histogram of Enhanced Image (BGR channels)

# %%
# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.imshow(img_eq, cmap='gray')
plt.title('original image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 plt.imshow(img_eq, cmap='gray')
#       6 plt.title('original image')
#       7 plt.show()
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\axes\_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File ~\.conda\envs\opencv\lib\site-packages\matplotlib\image.py:648, in _ImageBase._normalize_image_array(A)
#     646 A = cbook.safe_masked_invalid(A, copy=True)
#     647 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 648     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                     f"converted to float")
#     650 if A.ndim == 3 and A.shape[-1] == 1:
#     651     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Read the colorgiven parrot.jpg image.
img = cv2.imread('run.jpg', cv2.IMREAD_COLOR)

# %%
# Plot the histogram of colour image
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Plot the histogram of colour image
# ----> 2 img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# Convert to HSV.
img_hsv[:,:,2] = cv2.equalizeHist(img_hsv[:, :, 2])

# %%
# Perform histogram equalization
img_eq = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2BGR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Perform histogram equalization
# ----> 2 img_eq = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2BGR)
#
# NameError: name 'img_hsv' is not defined

# %%
# Convert back to BGR format
plt.subplot(121); plt.imshow(img[:, :, ::-1]); plt.title('Original Color Image')
plt.subplot(122); plt.imshow(img_eq[:, :, ::-1]); plt.title('Equalized Image')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Convert back to BGR format
# ----> 2 plt.subplot(121); plt.imshow(img[:, :, ::-1]); plt.title('Original Color Image')
#       3 plt.subplot(122); plt.imshow(img_eq[:, :, ::-1]); plt.title('Equalized Image')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Display
